# %% [markdown]
# # Variables , Expression and Statements

# %%
a = "Hello World"

type(a)
# Out:
# str

# %%
type(17)
# Out:
# int

# %%
type(1.3)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
print(100000)
# Out:
# 100000

# %%
print(10,00,00)
# Out:
# 10 0 0

# %%
print(10_00_00)
# Out:
# 100000

# %%
a = "hello_world"

# %%
salary = 100000
name = "Abhinav"
print(name, "earns", salary, "per month")
# Out:
# Abhinav earns 100000 per month

# %%
print(f"{name} earns {salary} per month")
# Out:
# Abhinav earns 100000 per month

# %%
print(f"{name} earns {salary * 2} per month")
# Out:
# Abhinav earns 200000 per month

# %%
salary_1st_person = 100000
print(f"{name} earns {salary_1st_person} per month")
# Out:
# Abhinav earns 100000 per month

# %%
# Snake case vs Camel case

# Snake case - Python convention
first_name = "Abhinav"
hr_salary = 100000
name = "Abhinav"

# Camel case - Java convention, Python
firstName = "Abhinav"

# %%
class = "Second"
# Out:
#   Cell In[16], line 1
#     class = "Second"
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
and_as = "hello"

# %% [markdown]
# ## Operators

# %%
20 +32
# Out:
# 52

# %%
hour = 7

# %%
minute = 60
hour * minute
# Out:
# 420

# %%
minute / hour
# Out:
# 8.571428571428571

# %%
a = 10
b = 20

a+b
# Out:
# 30

# %%
a -b
# Out:
# -10

# %%
a * b
# Out:
# 200

# %%
b / a
# Out:
# 2.0

# %%
type(b/a)
# Out:
# float

# %%
a = 59
b = 60

a / b
# Out:
# 0.9833333333333333

# %%
159/61
# Out:
# 2.6065573770491803

# %%
59 // 60
# Out:
# 0

# %%
20 / 10
# Out:
# 2.0

# %%
20 // 10
# Out:
# 2

# %%
59 // 60
# Out:
# 0

# %%
2 ** 4
# Out:
# 16

# %%
4 % 2
# Out:
# 0

# %%
4 % 3
# Out:
# 1

# %% [markdown]
# PEMDAS

# %%
2 ** 2 + (3 * 4) - (5 / 2)
# Out:
# 13.5

# %%
(13 + 4) * 2 - 3 ** 2
# Out:
# 25

# %%
a, b = 10, 20

# %%
b, a = a, b

# %%
a, b
# Out:
# (20, 10)

# %%
a = '10'
b = '20'
print(a + b)
# Out:
# 1020

# %%
# Typecast a to int
import builtins
type(builtins.int(a))
# Out:
# int

# %%
int("10")
# Out:
# 10

# %%
int = "hello"

# %%
int("10")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 int("10")
#
# TypeError: 'str' object is not callable

# %%
print(int(a) + int(b))
# Out:
# 30

# %%
"hello" * "Hello"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 "hello" * "Hello"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
"hello" * "hello"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 "hello" * "hello"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
print("hello" * 2)
# Out:
# hellohello

# %%
for i in range(5):
    print(f"Hello World {i}")
    print("X"* 20)
# Out:
# Hello World 0
# XXXXXXXXXXXXXXXXXXXX
# Hello World 1
# XXXXXXXXXXXXXXXXXXXX
# Hello World 2
# XXXXXXXXXXXXXXXXXXXX
# Hello World 3
# XXXXXXXXXXXXXXXXXXXX
# Hello World 4
# XXXXXXXXXXXXXXXXXXXX

# %%
x = input("Enter a number: ")

# %%
x
# Out:
# '10'

# %% [markdown]
# "\n"

# %%
print("Hello\nnumber")
# Out:
# Hello
# number

# %%
a = 10
print(a, end="***")
# Out:
# 10***

# %%
name = "Abhinav"
for i in name:
    print(i)
# Out:
# A
# b
# h
# i
# n
# a
# v
