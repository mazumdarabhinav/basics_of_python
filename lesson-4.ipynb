# %%
a = "Abhinav M"

# %% [markdown]
# ## String Slicing

# %%
len(a)
# Out:
# 9

# %% [markdown]
# Indexing always starts from 0.

# %%
a[1]
# Out:
# 'b'

# %% [markdown]
# sl = a[start_index:end_index]

# %%
a[0:2]
# Out:
# 'Ab'

# %%
a[-1]
# Out:
# 'M'

# %%
a[-4]
# Out:
# 'a'

# %%
a = "Abhinav M"

# %%
a[0:len(a):3]
# Out:
# 'Aiv'

# %% [markdown]
# sl = a[start_index:end_index:skip_value]

# %%
# Write a string slicing expression to get the string "bi" from the string "Abhinav M"
a[1:3]
# Out:
# 'bh'

# %%
a = 1
b = 0

try:
    result = a/b
    print(result)
except ZeroDivisionError:
    print("Error: Cannot divide by zero!")
# Out:
# Error: Cannot divide by zero!

# %%
a = "Abhinav"

# %%
len(a)
# Out:
# 7

# %%
if 'A' in a:
    print("Hello")
else:
    print("Bye")
# Out:
# Hello

# %%
s = "adsnAZ"

# %%
if s[-1:-3] == 'AZ':
    print("Hello")
else:
    print("Bye")
# Out:
# Bye

# %%
s[-1]
# Out:
# 'Z'

# %%
s = "adsnAZ"

# %%
s[-2:len(s) + 1]
# Out:
# 'AZ'

# %%
s[-3:]
# Out:
# 'nAZ'

# %%
s[-3:]

# %%
a = "Abhinav"

# %%
a[:3] # a[0:7]
# Out:
# 'Abh'

# %%
a[::2]
# Out:
# 'Ahnv'

# %% [markdown]
# a[start_index:end_index:skip]

# %%
a[::]
# Out:
# 'Abhinav'

# %%
a[:-1]
# Out:
# 'Abhina'

# %%
a[-3:-1:3]
# Out:
# 'n'

# %%
a = "Abhinav"

# %%
a[::-2]
# Out:
# 'vnhA'

# %%
class Person:
    def __init__(self, name, age, salary, has_house):
        self.name = name
        self.age = age
        self.salary = salary
        self.has_house = has_house

    def get_name(self):
        return self.name
    
    def increase_salary(self, increase_amount):
        return self.salary + increase_amount

# %%
class Person:
    def __init__(abhinav, name, age, salary, has_house):
        abhinav.name = name
        abhinav.age = age
        abhinav.salary = salary
        abhinav.has_house = has_house

    def get_name(abhinav):
        return abhinav.name
    
    def increase_salary(abhinav, increase_amount):
        return abhinav.salary + increase_amount

# %%
person1 = Person("Abhinav", 33, 10_000, True)
person2= Person("Sourav", 22, 20_000, False)

# %%
dir(person1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'get_name',
#  'has_house',
#  'increase_salary',
#  'name',
#  'salary']

# %%
person1.get_name()
# Out:
# 'Abhinav'

# %%
person1.name
# Out:
# 'Abhinav'

# %%
person1.get_name()
# Out:
# 'Abhinav'

# %%
person1.increase_salary(5000)
# Out:
# 15000

# %%
a = "Abhinav"

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
a = 1
dir(a)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %%
a.__str__()
# Out:
# '1'

# %%
a = "Abhinav"

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
a = "Abhinav"
a.endswith("iav")
# Out:
# False

# %%
a.startswith("Abh")
# Out:
# True

# %%
a = "AbbccccC"

# %%
a.count("c")
# Out:
# 4

# %%
c = "abhinav"
c.capitalize()
# Out:
# 'Abhinav'

# %%
c.upper()
# Out:
# 'ABHINAV'

# %%
"ABHINAV".lower()
# Out:
# 'abhinav'

# %%
a = "Abcccd"
a.find("c")
# Out:
# 2

# %%
a.replace("c", "x")
# Out:
# 'AbbxxxxC'

# %%
a = "Abbc"
a.lower()
# Out:
# 'abbc'

# %% [markdown]
# ## Escpace

# %%
print("A\nb")
# Out:
# A
# b

# %%
print("A\tb")
# Out:
# A	b

# %%
print("A'df")
# Out:
# A'df

# %%
a = "Abhinav "

# %%
new_string = a.replace(a.endswith(" "), "")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 new_string = a.replace(a.endswith(" "), "")
#
# TypeError: replace() argument 1 must be str, not bool

# %%
if a.endswith(" "):
    new_string = a[:-1]

# %%
new_string
# Out:
# 'Abhinav'

# %%
a = "Abhinav"

# %%
if a[-2:-1] == " ":
    a = a.replace(" ","")

# %%
a
# Out:
# 'Abhinav '

# %%
a.replace(a[len(a) -1 ], "")
# Out:
# 'Abhina'

# %%
a = "CCCCcccc"

# %%
a.count("Cc")
# Out:
# 1
