# %% [markdown]
# ## Conditional Expressions

# %% [markdown]
# ### Boolean expression

# %%
5 == 5
# Out:
# True

# %%
5 == 6
# Out:
# False

# %%
type(5 == 5)
# Out:
# bool

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ### Comparison operators

# %%
x, y = 5, 6

# %%
x == y # equality
# Out:
# False

# %%
x != y # not equal to
# Out:
# True

# %%
x > y
# Out:
# False

# %%
x < y
# Out:
# True

# %%
x >= y
# Out:
# False

# %%
x <= y
# Out:
# True

# %%
x = 5
y = 5

# %%
x == 5
# Out:
# True

# %%
x is y
# Out:
# True

# %% [markdown]
# == checks for actual value of two variable
#
# is checks if bt the variables are pointing to same memory location or not.

# %%
# memory llocation of x
id(x)
# Out:
# 4367723560

# %%
id(y)
# Out:
# 4367723560

# %%
x = x+ 1

# %%
x
# Out:
# 6

# %%
id(x)
# Out:
# 4367723592

# %%
id(y)
# Out:
# 4367723560

# %%
y
# Out:
# 5

# %%
x = 5
y = x

# %%
x
# Out:
# 5

# %%
y
# Out:
# 5

# %%
id(x), id(y)
# Out:
# (4367723560, 4367723560)

# %%
x = x+ 1

# %%
x
# Out:
# 6

# %%
y
# Out:
# 5

# %%
id(x), id(y)
# Out:
# (4367723592, 4367723560)

# %% [markdown]
# copy vs deep copy

# %%
x = 5

print(id(x))

x = x+ 1

print(id(x))
# Out:
# 4367723560
# 4367723592

# %%
x is y
# Out:
# True

# %%
x is not y
# Out:
# False

# %% [markdown]
# ## Logical Operators

# %% [markdown]
# AND OR NOT

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %%
# xor in python
(True ^ False) and (False ^ True) or (True ^ True) or (False ^ False)
# Out:
# True

# %%
True or False == True
# Out:
# True

# %%
1 == True
# Out:
# True

# %%
0 == False
# Out:
# True

# %%
1 and 0
# Out:
# 0

# %% [markdown]
# # Shallow copy vs Deep Copy

# %%
import copy

original_list = [[1, 2], [3, 4]]

# %%
shallow_copy = copy.copy(original_list)

# %%
original_list[0][0] = 99

# %%
print(f"Original: {original_list}")
print(f"Shallow:  {shallow_copy}")
# Out:
# Original: [[99, 2], [3, 4]]
# Shallow:  [[99, 2], [3, 4]]

# %%
original_list = [[1, 2], [3, 4]]

# %%
deep_copy = copy.deepcopy(original_list)

# %%
# Modify a nested item in the deep copy
deep_copy[0][0] = 99
print(f"Original: {original_list}")
print(f"Deep:     {deep_copy}")
# Out:
# Original: [[1, 2], [3, 4]]
# Deep:     [[99, 2], [3, 4]]

# %% [markdown]
# ## Mutuability vs Immutability

# %%
i = "Hello"
id(i)
# Out:
# 4424619552

# %%
i = i + " World"
id(i)
# Out:
# 4424794992

# %%
l = [1, 2, 3]
id(l)
# Out:
# 4424799616

# %%
l.append(4)
id(l)
# Out:
# 4424799616

# %%
i = "Hello"

i = i + " World"

# %%
i
# Out:
# 'Hello World'
